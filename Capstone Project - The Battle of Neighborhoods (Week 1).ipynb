# %% [markdown]
# # Peer-graded Assignment: Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ### Introduction & Business Problem

# %% [markdown]
# Problem:  Finding the best Neighborhood in Toronto by exploring some factors like area population,  income of people and as well as competitors so that business man can open a new restaurant.

# %% [markdown]
# ### Data

# %% [markdown]
# To collect & gather necessary information so that we can provide the important insights to superiors & stakeholders to make necessary action.
#
# For this, we will use Toronto offical data which is available on https://www.toronto.ca
#
# Note: **Data is publicaly available so there no need restrinction to use this**

# %%
#importing some required libraries

import numpy as np
import pandas as pd
import folium
print("Libraries have been imported!")
# Out:
# Libraries have been imported!

# %%
toronto_data = pd.read_csv("https://www.toronto.ca/ext/open_data/catalog/data_set_files/2016_neighbourhood_profiles.csv", encoding="latin1")
print("Data has been loaded!")
# Out:
# Data has been loaded!

# %% [markdown]
# **Now, Explore the data, we have collected:**

# %%
toronto_data.head()
# Out:
#                     Category                      Topic  \
# 0  Neighbourhood Information  Neighbourhood Information
# 1  Neighbourhood Information  Neighbourhood Information
# 2                 Population   Population and dwellings
# 3                 Population   Population and dwellings
# 4                 Population   Population and dwellings
#
#                       Data Source               Characteristic  \
# 0                 City of Toronto         Neighbourhood Number
# 1                 City of Toronto         TSNS2020 Designation
# 2  Census Profile 98-316-X2016001             Population, 2016
# 3  Census Profile 98-316-X2016001             Population, 2011
# 4  Census Profile 98-316-X2016001  Population Change 2011-2016
#
#   City of Toronto Agincourt North Agincourt South-Malvern West  \
# 0             NaN             129                          128
# 1             NaN  No Designation               No Designation
# ...

# %% [markdown]
# **Now, we will collect the Neighbourhood Names**

# %%
neigh_list = list(toronto_data.columns.values)[5:] #use indexing to remove uncessary data
neigh_list[:25]
# Out:
# ['Agincourt North',
#  'Agincourt South-Malvern West',
#  'Alderwood',
#  'Annex',
#  'Banbury-Don Mills',
#  'Bathurst Manor',
#  'Bay Street Corridor',
#  'Bayview Village',
#  'Bayview Woods-Steeles',
#  'Bedford Park-Nortown',
#  'Beechborough-Greenbrook',
#  'Bendale',
#  'Birchcliffe-Cliffside',
#  'Black Creek',
#  'Blake-Jones',
#  'Briar Hill-Belgravia',
#  'Bridle Path-Sunnybrook-York Mills',
#  'Broadview North',
#  'Brookhaven-Amesbury',
#  'Cabbagetown-South St. James Town',
#  'Caledonia-Fairbank',
#  'Casa Loma',
#  'Centennial Scarborough',
#  'Church-Yonge Corridor',
#  'Clairlea-Birchmount']

# %% [markdown]
# **Now, we will collect neighbourhood population**

# %%
#First Creating new dataset

population_data = pd.DataFrame(index=neigh_list, columns=["Population", "Income"])
population_data.head()
# Out:
#                              Population Income
# Agincourt North                     NaN    NaN
# Agincourt South-Malvern West        NaN    NaN
# Alderwood                           NaN    NaN
# Annex                               NaN    NaN
# Banbury-Don Mills                   NaN    NaN

# %% [markdown]
# **Now, Filling the data in population_data dataframe**

# %%
for index, row in population_data.iterrows():
    population_data.at[index, "Population"] = toronto_data[index][2]
    population_data.at[index, "Income"] = toronto_data[index][2264]
    
#printing the data
population_data.head()
# Out:
#                              Population   Income
# Agincourt North                  29,113   30,414
# Agincourt South-Malvern West     23,757   31,825
# Alderwood                        12,054   47,709
# Annex                            30,526  112,766
# Banbury-Don Mills                27,695   67,757

# %%
#Now, sort the data by income and see the result
population_data.sort_values("Income")
population_data
# Out:
#                              Population   Income
# Agincourt North                  29,113   30,414
# Agincourt South-Malvern West     23,757   31,825
# Alderwood                        12,054   47,709
# Annex                            30,526  112,766
# Banbury-Don Mills                27,695   67,757
# ...                                 ...      ...
# Wychwood                         14,349   54,460
# Yonge-Eglinton                   11,817   89,330
# Yonge-St.Clair                   12,528  114,174
# York University Heights          27,593   29,958
# Yorkdale-Glen Park               14,804   38,527
#
# [140 rows x 2 columns]
